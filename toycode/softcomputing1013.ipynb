0]) * (p2[1] - p3[1]) - (p2[0] - p3[0]) * (p1[1] - p2[1])
    if abs(det) < 1.0e-6:
        return (None, np.inf)
    # Center of circle
    cx = (bc*(p2[1] - p3[1]) - cd*(p1[1] - p2[1])) / det
    cy = ((p1[0] - p2[0]) * cd - (p2[0] - p3[0]) * bc) / det

    radius = np.sqrt((cx - p1[0])**2 + (cy - p1[1])**2)
    return ([cx, cy], radius)

# %%
c = list()
for k in range(198)[::3]:
    c.append(get_circle(*dot[k:k+3]))
c = np.array(c)
vis = [[],[],[]]
for p,r in zip(c[:,0],c[:,1]):
    vis[0].append(p[0])
    vis[1].append(p[1])
    vis[2].append(r)
    print(p, r)
# Out:
# [7.111589172143064e-09, 1.2792284409184677e-08] 1.999999985536474
# [-1.221419828371139e-09, 4.702983886885951e-10] 2.0000000008053114
# [9.291086401774835e-11, -1.2971342051558755e-11] 2.0000000000581224
# [-4.3080105778903144e-10, -1.4299158109310648e-10] 1.9999999997970912
# [1.0505709285245057e-10, 1.1199860849900766e-10] 1.9999999998950968
# [1.9082109925581386e-10, 8.684642863505075e-11] 2.0000000003510845
# [1.8147459929281816e-09, 9.056245633843826e-11] 2.0000000015286723
# [-2.413642299652963e-10, -6.616658333535703e-10] 1.9999999996059663
# [2.650556043184326e-10, 6.345515994541852e-10] 1.999999999687209
# [1.007321257498212e-09, -7.375128980413485e-10] 2.0000000002122174
# [-2.1713373168164523e-10, 2.3428543888633805e-11] 2.000000000209296
# [3.4773367380774832e-09, 7.426311242866484e-09] 1.9999999927209673
# [-4.070074337725513e-09, 7.919714689333146e-09] 2.0000000084972718
# [-4.754589089712752e-10, -2.1935518091108577e-10] 2.0000000003949787
# ...

# %%
plt.scatter(vis_dot[0][:100],vis_dot[1][:100])
plt.scatter(vis_dot[0][100:],vis_dot[1][100:])
plt.scatter(vis[0],vis[1])

# %%
import random
def rand3int(a=0, b=199):
    return [random.randint(a,b) for _ in range(3)]

# %%
c = list()
dot = np.array(dot)
for k in range(200):
    c.append(get_circle(*dot[rand3int()]))
c = np.array(c)
cxs = []
cys = []
rs = []
for p,r in zip(c[:,0],c[:,1]):
    if p is None:
        continue
    cxs.append(p[0])
    cys.append(p[1])
    rs.append(r)
cxs, cys, rs = np.array(cxs), np.array(cys), np.array(rs)
# Out:
# /Users/hobe/opt/anaconda3/envs/all/lib/python3.6/site-packages/ipykernel_launcher.py:5: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   """

# %%
plt.scatter(vis_dot[0][:100],vis_dot[1][:100])
plt.scatter(vis_dot[0][100:],vis_dot[1][100:])
plt.scatter(cxs,cys)

# %%
cxs = [-2<x<4 for x in cxs]
cys = [-2<y<2 for y in cys]
plt.scatter(vis_dot[0][:100],vis_dot[1][:100])
plt.scatter(vis_dot[0][100:],vis_dot[1][100:])
plt.scatter(cxs,cys)

# %%
c = list()
c2 = list()
c3 = list()
dot = np.array(dot)
# n^3
for i in range(200):
    for j in range(i,200):
        for k in range(j,200):
            if i<100 and j<100 and k<100:
                c.append(get_circle(dot[i],dot[j],dot[k]))
            elif i>100 and j>100 and k>100:
                c2.append(get_circle(dot[i],dot[j],dot[k]))
            else:
                c3.append(get_circle(dot[i],dot[j],dot[k]))
c = np.array(c+c2+c3)
cxs = []
cys = []
rs = []
temp = []
for p,r in zip(c[:,0],c[:,1]):
    if p is None or -2>p[0] or p[0]>4 or -2>p[1] or p[1]>2:
        continue
    temp.append((p,r))
    cxs.append(p[0])
    cys.append(p[1])
    rs.append(r)
cxs, cys, rs, c = np.array(cxs), np.array(cys), np.array(rs), np.array(temp)
# Out:
# /Users/hobe/opt/anaconda3/envs/all/lib/python3.6/site-packages/ipykernel_launcher.py:15: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   from ipykernel import kernelapp as app
# /Users/hobe/opt/anaconda3/envs/all/lib/python3.6/site-packages/ipykernel_launcher.py:27: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
plt.scatter(vis_dot[0][:100],vis_dot[1][:100])
plt.scatter(vis_dot[0][100:],vis_dot[1][100:])
plt.scatter(cxs,cys,color="RED")

# %%
plt.plot(cxs)

# %%
plt.plot(cys)

# %%
len(cxs)
# Out:
# 1054634

# %%
# for i in range(len(c))[::2]:
#     print(circle_distance(c[i],c[i+1]))

# %% [markdown]
# # [K-Means Clustering(K 평균 군집화) 개념 정리](https://eunsukimme.github.io/ml/2019/12/16/K-Means/)

# %%
c = list()
dot = np.array(dot)
# n^3
for i in range(200):
    for j in range(i,200):
        for k in range(j,200):
            c.append(get_circle(dot[i],dot[j],dot[k]))
c = np.array(c)
cidx = []
cxs = []
cys = []
rs = []
temp = []
for idx, (p, r) in enumerate(zip(c[:,0],c[:,1])):
    if p is None or -2>p[0] or p[0]>4 or -2>p[1] or p[1]>2 or r > 5:
        continue
    cidx.append(idx)
    temp.append((p,r))
    cxs.append(p[0])
    cys.append(p[1])
    rs.append(r)
x, y, r = np.array(cxs), np.array(cys), np.array(rs)
# Out:
# /Users/hobe/opt/anaconda3/envs/all/lib/python3.6/site-packages/ipykernel_launcher.py:8: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
knum = 2
# 랜덤으로 x, y 좌표 2개를 생성합니다
# np.random.uniform은 주어진 최소, 최대값 사이에서 k 개 만큼 실수 난수를 생성합니다.
centroids_x = np.random.uniform(min(x), max(x), knum)
centroids_y = np.random.uniform(min(y), max(y), knum)
centroids_r = np.random.uniform(min(r), max(r), knum)
centroids = np.array(list(zip(centroids_x, centroids_y, centroids_r)))

# %%
plt.scatter(x, y, alpha=0.5)	# 데이터들은 파란색으로 표시되고
plt.scatter(centroids_x, centroids_y)	# centroids는 주황색으로 표시됩니다
plt.show()

# %%
def circle_distance2(c1, c2):
    dis = norm(*c1[:2],*c2[:2])*(c1[2]**2 * c2[2]**2 * 2)
    return dis

# %%
# 각 데이터 포인트를 그룹화 할 labels을 생성합니다 (0, 1, 또는 2)
sepal_length_width = np.array(list(zip(x, y, r)))
labels = np.zeros(len(sepal_length_width))
# 각 데이터를 순회하면서 centroids와의 거리를 측정합니다
for i in range(len(sepal_length_width)):
    distances = np.zeros(knum)
    for j in range(k):
        distances[j] = circle_distance2(sepal_length_width[i], centroids[j])
    cluster = np.argmin(distances)	# np.argmin은 가장 작은 값의 index를 반환합니다
    labels[i] = cluster

# %%
plt.scatter(x, y, c=labels, alpha=0.5)
plt.scatter(centroids_x, centroids_y, c='red')	# centroid는 빨간색으로 나타냅니다
plt.show()

# %% [markdown]
# loop

# %%
from copy import deepcopy
centroids_old = deepcopy(centroids)
for i in range(knum):
  # 각 그룹에 속한 데이터들만 골라 points에 저장합니다
  points = [ sepal_length_width[j] for j in range(len(sepal_length_width)) if labels[j] == i ]
  # points의 각 feature, 즉 각 좌표의 평균 지점을 centroid로 지정합니다
  centroids[i] = np.mean(points, axis=0)

# %%
plt.scatter(x, y, c=labels, alpha=0.5)
plt.scatter(centroids_old[:, 0], centroids_old[:, 1], c='blue')
plt.scatter(centroids[:, 0], centroids[:, 1], c='red')
plt.show()

# %%
# 각 데이터 포인트를 그룹화 할 labels을 생성합니다 (0, 1, 또는 2)
sepal_length_width = np.array(list(zip(x, y, r)))
labels = np.zeros(len(sepal_length_width))
# 각 데이터를 순회하면서 centroids와의 거리를 측정합니다
for i in range(len(sepal_length_width)):
    distances = np.zeros(knum)
    for j in range(knum):
        distances[j] = circle_distance2(sepal_length_width[i], centroids[j])
    cluster = np.argmin(distances)	# np.argmin은 가장 작은 값의 index를 반환합니다
    labels[i] = cluster
plt.scatter(x, y, c=labels, alpha=0.5)
plt.scatter(centroids[:, 0], centroids[:,1], c='red')	# centroid는 빨간색으로 나타냅니다
plt.show()

# %%
len(c)
# Out:
# 1353400

# %%
#voting
vote = [(i,j,k) for i in range(200) for j in range(i,200) for k in range(j,200)]

# %%
len(vote)
# Out:
# 1353400

# %%
score = np.zeros(200)

# %%
len(labels)
# Out:
# 1054634

# %%
for idx in range(len(labels)):
    i,j,k = vote[cidx[idx]]
    score[i]+=labels[idx]
    score[j]+=labels[idx]
    score[k]+=labels[idx]

# %%
score
# Out:
# array([ 9605.,  8775.,  8580.,  6663., 10217.,  7431., 11718.,  6690.,
#         9805., 11799., 10807., 10547., 11498.,  8691.,  9977., 10097.,
#        11249.,  8171., 11555., 11162., 11800.,  8964., 10972., 11218.,
#         8945., 10508.,  6935.,  9538., 11415.,  9708., 10019.,  6911.,
#        11716., 10527., 10299.,  7956.,  8469.,  9574., 10227.,  6687.,
#        10341., 10582.,  7660., 11736., 11754., 11044., 11756.,  8354.,
#        11522., 10796., 10695.,  6663., 11776.,  6675., 10506.,  6751.,
#        10331.,  9859., 11402.,  6728., 10166., 11183., 11631.,  9471.,
#         9857.,  9158., 11468., 11801.,  8903., 10946.,  6746., 11451.,
#        11372., 10114.,  9754.,  6758., 11130.,  8049., 11792., 11119.,
#         8997., 11684., 11499., 11052., 10707., 10551., 10834., 11719.,
#         7330.,  6738.,  6670.,  7765., 11312., 10485., 11698.,  9477.,
#         7568.,  9681.,  9185.,  7394.,  5140.,   421.,  4984.,     0.,
# ...

# %%
score.mean()
# Out:
# 6510.855

# %%
color = score > score.mean()
color
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False,  True, False, False, False, False, False,
# ...

# %%
plt.scatter(vis_dot[0], vis_dot[1], c=color, alpha=0.5)

# %%
plt.scatter(vis_dot[0], vis_dot[1], c=color, alpha=0.5)

# %%
plt.scatter(vis_dot[0], vis_dot[1], c=color, alpha=0.5)

# %%
plt.scatter(vis_dot[0], vis_dot[1], c=color, alpha=0.5)

# %%
plt.scatter(vis_dot[0], vis_dot[1], c=color, alpha=0.5)
